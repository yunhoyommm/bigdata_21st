# %%
import mod1 as m

print(sum([3,4]))           # 내장 함수
print(m.sum(3,4))           # mod1 모듈 함수
print(m.safe_sum(1,'1'))
print(m.safe_sum(1,1))
# Out:
# 더할 수 있는 값 x
# 5
# 더할 수 있는 값 x
# 20.4

# %%
import mod1     # 이 줄만 실행해도 테스트 위한 print문까지 출력됨.
# Out:
# 더할 수 있는 값 x
# 5
# 더할 수 있는 값 x
# 20.4

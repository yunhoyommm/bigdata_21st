# %%
# 반복 명령 : for, while
# while : 몇 번 반복해야 할 지 모를 때 사용하는 명령
# 명령 구조  
# while 조건식 :
#   조건식이 True일 때 반복 실행할 코드

# %%
# 열 번 찍어 안 넘어가는 나무 없다.
treeHit = 1
while treeHit <= 10 :
    print(f"나무를 {treeHit}번 찍었습니다.")
print("나무가 넘어갑니다")

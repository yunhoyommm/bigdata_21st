# %%
data="""
park 800905-1049118
kim 700905-1059119
"""
result = [] # 최종 결과(주민번호 뒷자리 *)
#\n -> split -> list -> for 가능해짐
# data.split("\n")    # ['', 'park 800905-1049118', 'kim 700905-1059119', '']
for line in data.split("\n"):
    word_result = []
    for word in line.split():
        if len(word) == 14 and word[:6].isdigit() and word[7:].isdigit():
            word = word[:6] + "-*******"
        word_result.append(word)
    result.append(" ".join(word_result))
print("\n".join(result))
# Out:
# park 800905-*******
# kim 700905-*******

# %%
import re

data="""
park 800905-1049118
kim 700905-1059119
"""

pat = re.compile(r"(\d{6})[-]\d{7}")    # 소괄호가 그룹
# 패턴에 맞는 문자열 찾기. 
# p부터 시작(x) -> a부터 시작(x) -> r부터 시작(x) -> k부터 시작(x)
# " "부터 시작(x) -> 8부터 시작(o)
print(pat.sub(r"\g<1>-*******", data))  # \g<1> : 첫 번째 그룹 가져와라
# Out:
# park 800905-*******
# kim 700905-*******

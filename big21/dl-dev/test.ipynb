# %%
import torch
print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())     # cuda(GPU) 사용 가능하니?
print("CUDA version:", torch.version.cuda)              # GPU에 따라 cuda version 다름.
print("GPU:", torch.cuda.get_device_name(0))            # 회사 가면 GPU 4~5개 있을 수 있음. 따로따로 제어 가능.
# Out:
# PyTorch: 2.5.1
# CUDA available: True
# CUDA version: 11.8
# GPU: NVIDIA GeForce GTX 1660 SUPER

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
